# %%
import requests
import pandas as pd
from datetime import datetime

url = "https://earthquake.usgs.gov/fdsnws/event/1/query"

all_records = []
start_year = datetime.now().year - 5   # last 5 years
end_year = datetime.now().year

for year in range(start_year, end_year + 1):
    for month in range(1, 13):
        start_date = f"{year}-{month:02d}-01"
        if month == 12:
            end_date = f"{year+1}-01-01"
        else:
            end_date = f"{year}-{month+1:02d}-01"

        params = {
            "format": "geojson",
            "starttime": start_date,
            "endtime": end_date,
            "minmagnitude": 3
        }

        response = requests.get(url, params=params)
        if response.status_code != 200:
            print(f"⚠️ Failed for {start_date}: {response.text[:200]}")
            continue

        try:
            data = response.json()
        except Exception as e:
            print(f"⚠️ JSON error for {start_date}: {e}")
            continue
        #print(data)
        #break
        for f in data["features"]:
            p = f["properties"]
            g = f["geometry"]["coordinates"]
           
            all_records.append({
                "id": f.get("id"),
                "time": pd.to_datetime(p.get("time"), unit="ms"),
                "updated": pd.to_datetime(p.get("updated"), unit="ms"),
                "latitude": g[1] if g else None,
                "longitude": g[0] if g else None,
                "depth_km": g[2] if g else None,
                "mag": p.get("mag"),
                "mag_Type": p.get("magType"),
                "place": p.get("place"),
                "status": p.get("status"),
                "tsunami": p.get("tsunami"),
                "alert": p.get("alert"),
                "felt": p.get("felt"),
                "cdi": p.get("cdi"),
                "mmi": p.get("mmi"),
                "sig": p.get("sig"),
                "net": p.get("net"),
                "code": p.get("code"),
                "ids": p.get("ids"),
                "Sources": p.get('sources'),
                "types": p.get("types"),
                "nst": p.get("nst"),
                "dmin": p.get("dmin"),
                "rms": p.get("rms"),
                "gap": p.get("gap"),
                "type": p.get("type")        
               



                # Event type
            })

df = pd.DataFrame(all_records)


print("ROWS,Columns:", df.shape[0],df.shape[1])
print(df.head())
# Out:
# ROWS,Columns: 106644 26
#            id                    time                 updated  latitude  \
# 0  us6000ddi8 2021-01-31 23:20:49.923 2021-04-16 19:02:44.040  -31.7493
# 1  us6000dev6 2021-01-31 23:08:17.161 2021-04-16 19:03:47.040  -15.4902
# 2  us6000dev5 2021-01-31 22:54:19.760 2021-04-16 19:03:47.040   19.7529
# 3  us6000ddhs 2021-01-31 22:06:00.832 2021-04-16 19:02:43.040   28.1524
# 4  us6000dev4 2021-01-31 21:51:14.016 2021-04-16 19:03:46.040   71.3212
#
#    longitude  depth_km  mag mag_Type  \
# 0   -68.9337     17.27  4.7      mwr
# 1  -177.2052    426.71  4.1       mb
# 2   121.3159     46.73  4.7       mb
# 3    57.2570     10.00  4.9       mb
# 4    -3.7578     10.00  4.0       mb
#
#                                                place    status  ...  net  \
# 0        29 km SW of Villa Basilio Nievas, Argentina  reviewed  ...   us
# 1                                        Fiji region  reviewed  ...   us
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106644 entries, 0 to 106643
# Data columns (total 26 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         106644 non-null  object
#  1   time       106644 non-null  datetime64[ns]
#  2   updated    106644 non-null  datetime64[ns]
#  3   latitude   106644 non-null  float64
#  4   longitude  106644 non-null  float64
#  5   depth_km   106644 non-null  float64
#  6   mag        106644 non-null  float64
#  7   mag_Type   106644 non-null  object
#  8   place      106644 non-null  object
#  9   status     106644 non-null  object
#  10  tsunami    106644 non-null  int64
#  11  alert      4371 non-null    object
#  12  felt       16585 non-null   float64
#  13  cdi        16585 non-null   float64
#  14  mmi        8870 non-null    float64
#  15  sig        106644 non-null  int64
#  16  net        106644 non-null  object
#  17  code       106644 non-null  object
# ...

# %%
df.to_csv("earthquake.csv")

# %%
df["id"]=df["id"].fillna(df["id"].mode())

# %%
df["latitude"]=df["latitude"].fillna(df["latitude"].mean())

# %%
df["longitude"]=df["longitude"].fillna(df["longitude"].mean())

# %%
df["depth_km"]=df["depth_km"].fillna(df["depth_km"].mean())

# %%
df["mag"]=df["mag"].fillna(df["mag"].mean())

# %%
df["mag_Type"]=df["mag_Type"].fillna(df["mag_Type"].mode())

# %%
df["place"]=df["place"].fillna(df["place"].mode())

# %%
df["status"]=df["status"].fillna(df["status"].mode())

# %%
df["tsunami"]=df["tsunami"].fillna(df["tsunami"].mean())

# %%
df["alert"]=df["alert"].fillna(("green"))

# %%
df["felt"]=df["felt"].fillna(df["felt"].mean())

# %%
df["cdi"]=df["cdi"].fillna(df["cdi"].mean())

# %%
df["mmi"]=df["mmi"].fillna(df["mmi"].mean())

# %%
df["sig"]=df["sig"].fillna(df["sig"].mean())

# %%
df["net"]=df["net"].fillna(df["net"].mode())

# %%
df["code"]=df["code"].fillna(df["code"].mode())

# %%
df["ids"]=df["ids"].fillna(df["ids"].mode())

# %%
df["Sources"]=df["Sources"].fillna(df["Sources"].mode())

# %%
df["types"]=df["types"].fillna(df["types"].mode())

# %%
df["nst"]=df["nst"].fillna(df["nst"].mean())

# %%
df["dmin"]=df["dmin"].fillna(df["dmin"].mean())

# %%
df["rms"]=df["rms"].fillna(df["rms"].mean())

# %%
df["gap"]=df["gap"].fillna(df["gap"].mean())

# %%
df["type"]=df["type"].fillna(df["type"].mode())

# %%
import pymysql
try:
 # Connecting to mysql using Parameters
 connection = pymysql.connect( host = 'localhost', user = 'root', 
 password = '123kam456', database = 'project1',cursorclass=pymysql.cursors.DictCursor
 )
 print("connected to mysql success")
except Exception as e:
 print("connection failed",e)

#create table('earthquakes') and push to workbench
# push datas from vs to mysql table('earthquakes')

import sqlalchemy as sqlalchemy
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:123kam456@localhost/project1")
df.to_sql(
 name='earthquakes_1', # table name
 con=engine,
 if_exists='append', # insert data (no overwrite)
 index=False # avoid DataFrame index column
 )
print("Data inserted successfully to mysql")
# Out:
# connected to mysql success
# Data inserted successfully to mysql
